# %% [markdown]
# # Nonlinear Partial Differential Equations
#
# Dr. James Kennedy<br>
# Institut fur Analysis<br>
# Universitat Ulm
#
# Summer Semester 2016
#
# ## Chapter 1 - Introduction, Notation and Definitions
